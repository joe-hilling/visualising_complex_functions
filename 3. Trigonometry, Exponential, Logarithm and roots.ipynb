# %%
# %matplotlib inline 
from domain_colourings import hsv1,rgb1,rgbLog,rgbReal
from plot_apparatus import ComplexPlot
from polynomials import Polynomial
import numpy as np
from numpy.random import random
import functions as fn

# Create a plotting object defaults to hsv
cPlot = ComplexPlot(hsv1)

# Domain Colourings
colArr = [hsv1, rgb1, rgbLog(10)]

# Setup view
cPlot.view(2.5)
cPlot.pointDensity = 200

# %%
cPlot.plotMultiColorings('cos(z)', np.cos, colArr)

# %%
cPlot.plotMultiColorings('sin(z)', np.sin, colArr)

# %%
cPlot.plotMultiColorings('cosh(z)', np.cosh, colArr)

# %%
cPlot.plotMultiColorings('sinh(z)', np.sinh, colArr)

# %%
cPlot.plotMultiColorings('tan(z)', np.tan, colArr)

# %%
cPlot.plotMultiColorings('tanh(z)', np.tanh, colArr)

# %%
cPlot.plotMultiColorings('exp(z)', np.exp, colArr)

# %%
cPlot.plotMultiColorings('ln(z)', np.log, colArr)

# %%
cPlot.plotMultiColorings('sqrt(z)', np.sqrt, colArr)

# %%
cPlot.plotMultiColorings('-sqrt(z)', lambda z: -np.sqrt(z), colArr)
